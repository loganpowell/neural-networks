# %%
import json
import sys
sys.path.append("../")

from fns.azure_fns import write_file, read_file

# RESET KV STORE 🔥
# write_file("benchmarks/kv.json", json.dumps({}, indent=2))

# print(read_file("benchmarks/kv.json"))
# print(json.dumps(results, indent=4, sort_keys=True))

# %% [markdown]
# ## Azure CLI Commands
#
# https://learn.microsoft.com/en-us/cli/azure/group?view=azure-cli-latest
#
# ## Cosmos Notebooks
#
# [Cosmos RAGs]
#
# - Gremlin
#   - [gremlin starter]
#   - [other gremlin examples]
#
# ## Ideas
#
# ### Recommender
#
# keep track of nodes visited by a user and find mutual connections between those nodes (online updates)
#
# ### Beginner
#
# - If the user is a beginner, bump the `important` link (many inbound links) - more likely to be relevant
# - If the user asks a simple question and then asks another question, we determine she is a newb and bump the `important` link
#
# ### Content Analysis
#
# - if there are few or no mutual connections between the nodes, ask for disambiguation
# - community detection
# - topic modeling
# - centrality
# - next-best action
# - recommendations
#
# ### User Profile Generation
#
# #### Individual
#
# - `niche` number: query complexity proxy: use inbound links as a metric to determine how niche the answer is - thus how complex the query is
#   - if the user asks x (e.g., 3) questions with a average/cumulative inbound link count of y (e.g., 5), we determine the user is a beginner
#   - how to leverage the profile:
#
# #### Cohort
#
# - use graph traversal activities to cluster users based on their activity
# - recommendations
# - social networks
# - communities
# - user groups/personas
# - customer journey mapping
#
# MEAN inbound edges for sample 500 = 4.31
#
# ## Pros Cons
#
# ### Graph Databases
# - pros:
#   - Designed for surfacing/discovering relationships (direct and indirect) between entities
#   - Analysis can be done on the entire graph relatively quickly
#   - Summary statistics can be generated with ease
# - cons:
#   1. Requires modeling the data as a graph, which the data may not - unaltered - be conducive to
#   2. Subgraph traversal relevance is dependent upon picking relevant entry point (i.e., related entities to irrelevant entities produces irrelevant results)
# - remediation techniques:
#   1. Use LLM to generate graph entities from plain text (narrative) data
#   2. Use a hybrid approach (e.g., graph + vector) to leverage the strengths of both
#
# ### Vector Databases
# - pros:
#   - Designed for easy and fast retrieval of similar pieces of text
#   - Relationships are not directly modeled, but rather inferred by their proximity in the vector space (easy)
# - cons:
#   1. Result quality highly dependent on the quality of the query
#   2. May return results that are similar to the query, but from widely different contexts
# - remediation techniques:
#   1. Provide suggestions to the user to refine their query
#   2. Use methods of disambiguation to determine the context of the query
#
# ## Opportunities
# - hash table of titles/headings to vectors to find entry-point for traversal
# - inbound -> outbound customer journey assistance
# - follow-up questions (related articles from articles/chunks)
# - profiling users based on their visitation patterns (customer journey/cohorts/personas)
#
# [Cosmos RAGs]: https://github.com/microsoft/AzureDataRetrievalAugmentedGenerationSamples/blob/main/Python/CosmosDB-MongoDB-vCore/CosmosDB-MongoDB-vCore_AzureOpenAI_Tutorial.ipynb
# [gremlin starter]: https://github.com/Azure-Samples/azure-cosmos-db-graph-python-getting-started/blob/master/connect.py
# [other gremlin examples]: https://github.com/search?q=org%3AAzure-Samples%20gremlin&type=code

# %%
import nest_asyncio
from fns.rag_fns import get_community
from fns.azure_fns import graph_get_most_connected
nest_asyncio.apply()

# results = get_community("How do you calculate tax in the state of PA?")
# results = get_community("How do I add a taxpayer?")

# results = get_community("Where can I find information on how to integrate the Exemption Certificate Wizard?") 
# No match

# What is the purpose of the Buyer Input Tax event?
# -> Financial events in O Series	Asset/Goods Movement event
# results = get_community("What is the purpose of the Buyer Input Tax event?") 
# Match in 3rd kb result > 2nd idx sibling

# What is the maximum number of characters that can be used for the taxpayer's code
# -> Provide general taxpayer information in O Series	Field descriptions for the Taxpayers > General tab Part 1
# results = get_community("What is the maximum number of characters that can be used for the taxpayer's code in O Series?") 
# works if you add 'in O Series'  and grab the 3rd kb result > 1st idx sibling

# What are the different tabs available in the customer setup process and what information is entered
# -> Set up your customers in O Series	Navigate to the Customer feature
# results = get_community("What are the different tabs available in the customer setup process in O Series?") 
# ✅ works if you add 'in O Series' to the question

# What is the jurisdiction and imposition type for the tax that is paid by the buyer
# -> MATCHED!	Test for Brazil ISS - Intercity service provider perspective
# results = get_community("What is the jurisdiction and imposition type for the tax that is paid by the buyer?")
# match in 2nd kb result > 0th idx sibling

# What does the Includes Taxable Amount check box indicate?	
# -> Specify details for a post calculation evaluation rule	Field descriptions for Post Calculation Evaluation rule > Details tab Part 2
# results = get_community("What does the 'Includes Taxable Amount' check box indicate Taxability Review and Data Export Methods")
# works if you add 'for a post calculation' to the question and grab the 3rd kb result > 3rd idx sibling

# What does the Is Service column indicate in the report?
# -> Transaction Detail extract in O Series Custom Reports - VRA	Notes: Part 12
# results = get_community("What does the Is Service column indicate in the report?")
# ✅ gets the right result, but the product isn't labeled O Series Cloud (mislabelled)

# What are the default values for the O Series configuration parameters in ITI?
# -> O Series configuration parameters for ITI	O Series configuration parameters for ITI Part 2
# results = get_community("What are the default values for the O Series configuration parameters in ITI?")
# FIXME: `important`, `mutuals` and `siblings` are all empty because they are all chunks from the same page
# gets the right page, but not the right chunk ("Part 2")

# What prerequisites and setup information do I need to be aware of before extracting data from
# -> Extracting data from SAP for ITI	Extracting data from SAP for ITI
# results = get_community("What prerequisites and setup information do I need to be aware of before extracting data from SAP for ITI?")
# gets correct chunk, but same problem as above, all chunks are from the same page

# What are the required user authentication parameters for O Series On-Premise and On
# -> Command line utility: getFile	Command line utility: getFile
# results = get_community("What are the required user authentication parameters for file downloads?")
# gets the correct answer if you add "for file downloads" to the question


# What are the line-item level tabs in the O Series Transaction Tester?	
# -> Set up line-item details in the O Series Transaction Tester	Set up line-item details in the O Series Transaction Tester
results = get_community("What are the line-item level tabs in the O Series Transaction Tester?")
# ✅ works now 🤔 

# What data elements were added to the O Series 9.0 schema to support
# -> XML schema changes for Communications Tax in O Series 9.0	New communications tax data elements
# results = get_community("What data elements were added to the O Series 9.0 schema to support communications tax?")
# ✅ looks like it works now :: content seems to change a lot


# What is the purpose of the batch.client.userName parameter in the Batch Client
# -> Process a BCI database using runBatchClientInterface in Client Utilities	Process a BCI database using runBatchClientInterface in Client Utilities
# results = get_community("What is the purpose of the 'batch.client.userName' parameter in the Batch Client?")
# ✅ actually gets a good result, not the one specified in the benchmark though




print(json.dumps(results, indent=4))

# connections = graph_get_most_connected(["COSMyEnterprise:en:Taxpayers", 'COSMyEnterprise:en:169626', 'COSMyEnterprise:en:169591'], "both")
# print(json.dumps(connections, indent=4))
# Out:
# graph_get_connected Query: g.V('COSTools:en:185493').out('parent').has('heading', 'Set up line item details in the O Series Transaction Tester').tree()
# graph_get_connected Query: g.V('COSTools:en:185493').out('parent').tree()
# node_id: COSTools:en:185493
# url: https://community.vertexinc.com/s/document-item?bundleId=COSTools&topicId=185493.html&_LANG=enus
# heading: Set up line item details in the O Series Transaction Tester
# graph_get_connected Query: g.V('COSTools:en:185493').out('related').tree()
# graph_get_connected Query: g.V('COSTools:en:185493:0').out('related').tree()
# graph_get_connected Query: g.V('COSTools:en:185341').out('parent').has('heading', 'Line Type codes in O Series').tree()
# graph_get_connected Query: g.V('COSTools:en:185341').out('parent').tree()
# node_id: COSTools:en:185341
# url: https://community.vertexinc.com/s/document-item?bundleId=COSTools&topicId=185341.html&_LANG=enus
# heading: Line Type codes in O Series
# graph_get_connected Query: g.V('COSTools:en:185341').out('related').tree()
# graph_get_connected Query: g.V('COSTools:en:185634').out('parent').has('heading', 'O Series Transaction Tester Other tab for line items').tree()
# graph_get_connected Query: g.V('COSTools:en:185634').out('parent').tree()
# node_id: COSTools:en:185634
# url: https://community.vertexinc.com/s/document-item?bundleId=COSTools&topicId=185634.html&_LANG=enus
# heading: O Series Transaction Tester Other tab for line items
# graph_get_connected Query: g.V('COSTools:en:185634').out('related').tree()
# graph_get_connected Query: g.V('COSTools:en:185634:0').out('related').tree()
# graph_get_in_common Query: g.V("COSTools:en:185493:0", "COSTools:en:185634:0").aggregate('provided').both().where(without('provided')).groupCount()
# graph_get_most_connected Query: g.V().hasId("COSTools:en:185493:0", "COSTools:en:185634:0").project('vertex', 'degree').by().by(inE().count()).order().by(select('degree'), decr)
# {
#     "inbound_links": {
#         "COSTools:en:185634:0": 1,
#         "COSTools:en:185493:0": 1
#     },
#     "mutuals": {
#         "COSTools:en:185634": 3,
#         "COSTools:en:185434": 1,
#         "COSTools:en:185006": 1,
#         "COSTools:en:185493": 2,
#         "COSTools:en:185128": 1,
#         "COSTools:en:185680": 1,
#         "COSTools:en:185341": 1,
#         "COSTools:en:185389": 1,
#         "COSTools:en:185123": 1,
#         "COSTools:en:186688": 1,
#         "COSTools:en:184839": 1,
#         "COSTools:en:184972": 1,
#         "COSTools:en:204864": 1
#     },
#     "kb_results": [
#         {
#             "url": "https://community.vertexinc.com/s/document-item?bundleId=COSTools&topicId=185493.html&_LANG=enus",
#             "@search.score": 0.89921236,
#             "content": "   Set up line-item details in the O Series Transaction Tester  When using Transaction Tester in Vertex\u00ae O Series to test a transaction, setting up line-item detail is an optional second stage of  the transaction building process. It's most efficient to specify transaction information  first and to then identify line-item details that differ from the transaction selections.  When working with line items, keep these guidelines in mind:  * You must identify at least one line item on either the transaction or line-item Basic  tab, but you can add any number of line items on the line-item Basic tab. * You can set up multi-component line items, so that any line item can include any number  of child line items. * Each line item must have an amount for tax calculation. * Each line item inherits selections from the level above.     Inherited properties  Each line item inherits selections from the level above, unless you specify something  different for that line item. The highest level of line items inherits the transaction-level  selections, and a child line item inherits the selections from its parent line items.  Fields that inherit values from the transaction or parent line item are identified  with .  A word about codes \u2013 to change a code that is inherited, you can click next to the code field to select a code from the data in your O Series database. Codes and class codes are case-sensitive. Entering abc in a Code field  does not detect a match for a code of ABC. If codes that you enter are either not  defined or do not match codes in your system, tax is calculated using default rates  and rules.     The line item tabs  These are the line-item level tabs. Depending on the financial event you select, some  of the tabs may not be available. You can find descriptions for a tab by clicking  the tab link.  * Basic * Addresses * Registrations * Participants * Amounts * Input Tax * Taxability Drivers * Flex Fields * Overrides * Other * Returns Fields",
#             "title": "Set up line-item details in the O Series Transaction Tester",
#             "heading": "Set up line-item details in the O Series Transaction Tester",
#             "product": [
#                 "O Series Cloud",
#                 "O Series On Demand",
#                 "O Series On Premise"
#             ]
#         },
#         {
#             "url": "https://community.vertexinc.com/s/document-item?bundleId=COSTools&topicId=185341.html&_LANG=enus",
#             "@search.score": 0.8895144,
#             "content": "Line Type codes in O Series      Related articles  Overview of Transaction Tester  The process of building a transaction in Transaction Tester  Set up transaction information in Transaction Tester  Set up line-item details in Transaction Tester  View transaction results",
#             "title": "O Series Transaction Tester > Taxability Drivers tab for line items",
#             "heading": "Line Type codes in O Series",
#             "product": [
#                 "O Series Cloud",
#                 "O Series On Demand",
#                 "O Series On Premise"
#             ]
#         },
#         {
#             "url": "https://community.vertexinc.com/s/document-item?bundleId=COSTools&topicId=185634.html&_LANG=enus",
#             "@search.score": 0.8857452,
#             "content": "  O Series Transaction Tester > Other tab for line items  When setting up line-item information so you can test a transaction, use the Other  tab in Vertex\u00ae O Series to include supplemental information in the transaction request. This information  enhances the ability to report on the line item.  The fields or check boxes that display depend on which financial event you are using  to create the transaction.     Enter supplemental information  1. Navigate to Tools > Transaction Tester > Single Transaction. 2. Switch to the line-item level in either of these ways:  \t* In the selector at the top right of the Single Transaction page, select Line Item from the drop-down list. \t* In the Line Items area at the bottom of the transaction-level Basic tab, click Edit in the Actions column. 3. Select the Other tab. 4. Select pertinent field values as explained in \"Field descriptions\" below.",
#             "title": "O Series Transaction Tester > Other tab for line items",
#             "heading": "O Series Transaction Tester > Other tab for line items",
#             "product": [
#                 "O Series Cloud",
#                 "O Series On Demand",
#                 "O Series On Premise"
#             ]
#         }
#     ],
#     "graph_results": [
#         {
#             "url": "https://community.vertexinc.com/s/document-item?bundleId=COSTools&topicId=185493.html&_LANG=enus",
#             "node_id": "COSTools:en:185493",
#             "heading": "Set up line item details in the O Series Transaction Tester",
#             "title": "Set up line-item details in the O Series Transaction Tester",
#             "modified_by": "pcx_department_service",
#             "created_by": "josborn",
#             "chunk_id": "COSTools:en:185493:0",
#             "chunk_links": [
#                 {
#                     "id": "COSTools:en:185434",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:185006",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:185128",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:185680",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:185341",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:185389",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:185123",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:186688",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:184839",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:184972",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:185634",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:204864",
#                     "label": "topic",
#                     "type": "vertex"
#                 }
#             ],
#             "related_articles": [
#                 {
#                     "id": "COSTools:en:TransactionTester",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:183782",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:183784",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:179697",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:185492",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:183783",
#                     "label": "topic",
#                     "type": "vertex"
#                 }
#             ],
#             "page_chunks": [
#                 {
#                     "id": "COSTools:en:185493:0",
#                     "label": "chunk",
#                     "type": "vertex",
#                     "title": "Set up line item details in the O Series Transaction Tester",
#                     "heading": "Set up line item details in the O Series Transaction Tester",
#                     "md": " Set up line item details in the O Series Transaction Tester When using Transaction Tester in Vertex O Series to test a transaction setting up line item detail is an optional second stage of the transaction building process It s most efficient to specify transaction information first and to then identify line item details that differ from the transaction selections When working with line items keep these guidelines in mind You must identify at least one line item on either the transaction or line item Basic tab but you can add any number of line items on the line item Basic tab You can set up multi component line items so that any line item can include any number of child line items Each line item must have an amount for tax calculation Each line item inherits selections from the level above Inherited properties Each line item inherits selections from the level above unless you specify something different for that line item The highest level of line items inherits the transaction level selections and a child line item inherits the selections from its parent line items Fields that inherit values from the transaction or parent line item are identified with A word about codes to change a code that is inherited you can click next to the code field to select a code from the data in your O Series database Codes and class codes are case sensitive Entering abc in a Code field does not detect a match for a code of ABC If codes that you enter are either not defined or do not match codes in your system tax is calculated using default rates and rules The line item tabs These are the line item level tabs Depending on the financial event you select some of the tabs may not be available You can find descriptions for a tab by clicking the tab link Basic Addresses Registrations Participants Amounts Input Tax Taxability Drivers Telecom Lines Flex Fields Overrides Other Returns Fields",
#                     "order": 0
#                 },
#                 {
#                     "id": "COSTools:en:185493:1",
#                     "label": "chunk",
#                     "type": "vertex",
#                     "title": "Set up line item details in the O Series Transaction Tester",
#                     "heading": "Enter the line item details",
#                     "md": " Enter the line item details After you specify transaction information provide line item details 1 Switch to the line item perspective in one of these ways From the selector in the upper right of the page select the Line Item you want to define In the Line Items area at the bottom of the transaction level Basic tab click Edit in the Actions column for the line item you want to define The Transaction Tester displays the line item Basic tab by default 2 For line item details that differ from the parent line item or the transaction information access the appropriate tabs and make your selections For information about a specific tab and fields click the tab link in The line item tabs above 3 When you are satisfied with your selections for the transaction and the line items click Calculate to run the transaction You can view the transaction results by clicking the XML tab ",
#                     "order": 1
#                 }
#             ]
#         },
#         {
#             "url": "https://community.vertexinc.com/s/document-item?bundleId=COSTools&topicId=185341.html&_LANG=enus",
#             "node_id": "COSTools:en:185341",
#             "heading": "Line Type codes in O Series",
#             "title": "O Series Transaction Tester > Taxability Drivers tab for line items",
#             "modified_by": "pcx_department_service",
#             "created_by": "josborn",
#             "chunk_id": null,
#             "chunk_links": [],
#             "related_articles": [
#                 {
#                     "id": "COSTools:en:185493",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:TransactionTester",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:185492",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:179697",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:183782",
#                     "label": "topic",
#                     "type": "vertex"
#                 }
#             ],
#             "page_chunks": [
#                 {
#                     "id": "COSTools:en:185341:0",
#                     "label": "chunk",
#                     "type": "vertex",
#                     "title": "O Series Transaction Tester Taxability Drivers tab for line items",
#                     "heading": "O Series Transaction Tester Taxability Drivers tab for line items",
#                     "md": " O Series Transaction Tester Taxability Drivers tab for line items Use the Taxability Drivers tab in Vertex O Series to provide the taxability driver codes that can impact the taxability of the goods or services on a line item Be aware that This tab contains fields for general taxability drivers Telecom specific taxability drivers are located on the Telecom Lines tab Identifiers for Product Purchase and Usage are redundant on the Basic tab and the Taxability Drivers tab Information that is entered on either tab displays on both Identify the taxability drivers for the line item 1 Navigate to Tools Transaction Tester Single Transaction 2 Switch to the line item level in either of these ways In the selector at the top right of the Single Transaction page select Line Item from the drop down list In the Line Items area at the bottom of the transaction level Basic tab click Edit in the Actions column 3 Select the Taxability Drivers tab 4 Select pertinent field values as explained in Field descriptions below ",
#                     "order": 0
#                 },
#                 {
#                     "id": "COSTools:en:185341:1",
#                     "label": "chunk",
#                     "type": "vertex",
#                     "title": "O Series Transaction Tester Taxability Drivers tab for line items",
#                     "heading": "Field descriptions for the line item Taxability Drivers tab",
#                     "md": " Field descriptions for the line item Taxability Drivers tab This table explains the fields on the Taxability Drivers tab Here are some tips for identifying a driver You can type a driver identifier directly in the field Be sure to type the identifier exactly as it exists in the database When manually entering the identifier if you have selected a taxpayer at the transaction level O Series lists taxability drivers for that taxpayer that match the characters you type You can select the driver from that list To search for an identifier via the magnifying glass you must first select a taxpayer at the transaction level Field Description Product Product Class In a Supplies transaction the goods or services for the line item Purchase Purchase Class In Procurement transactions the goods or services for the line item Usage Usage Class A code that represents an intended use of the goods or services on the line item Cost Center An identifier for a cost center within an organization This code is usually related to the functional or accounting responsibilities Department Code An identifier for a department within an organization This code usually identifies a specific direct sub entity of a taxpayer or division General Ledger Account An identifier for a General Ledger Account number from your Chart of Accounts Material Code An identifier for a specific asset type Project Number An identifier for indicating that the line item is billable to a specific project Vendor SKU An identifier for indicating a Stock Keeping Unit from a vendor s catalog ",
#                     "order": 1
#                 }
#             ]
#         },
#         {
#             "url": "https://community.vertexinc.com/s/document-item?bundleId=COSTools&topicId=185634.html&_LANG=enus",
#             "node_id": "COSTools:en:185634",
#             "heading": "O Series Transaction Tester Other tab for line items",
#             "title": "O Series Transaction Tester > Other tab for line items",
#             "modified_by": "pcx_department_service",
#             "created_by": "josborn",
#             "chunk_id": "COSTools:en:185634:0",
#             "chunk_links": [],
#             "related_articles": [
#                 {
#                     "id": "COSTools:en:185493",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:185492",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:TransactionTester",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:179697",
#                     "label": "topic",
#                     "type": "vertex"
#                 },
#                 {
#                     "id": "COSTools:en:183782",
#                     "label": "topic",
#                     "type": "vertex"
#                 }
#             ],
#             "page_chunks": [
#                 {
#                     "id": "COSTools:en:185634:0",
#                     "label": "chunk",
#                     "type": "vertex",
#                     "title": "O Series Transaction Tester Other tab for line items",
#                     "heading": "O Series Transaction Tester Other tab for line items",
#                     "md": " O Series Transaction Tester Other tab for line items When setting up line item information so you can test a transaction use the Other tab in Vertex O Series to include supplemental information in the transaction request This information enhances the ability to report on the line item The fields or check boxes that display depend on which financial event you are using to create the transaction Enter supplemental information 1 Navigate to Tools Transaction Tester Single Transaction 2 Switch to the line item level in either of these ways In the selector at the top right of the Single Transaction page select Line Item from the drop down list In the Line Items area at the bottom of the transaction level Basic tab click Edit in the Actions column 3 Select the Other tab 4 Select pertinent field values as explained in Field descriptions below ",
#                     "order": 0
#                 },
#                 {
#                     "id": "COSTools:en:185634:1",
#                     "label": "chunk",
#                     "type": "vertex",
#                     "title": "O Series Transaction Tester Other tab for line items",
#                     "heading": "Field descriptions for the line item Other tab Part 1",
#                     "md": "Field descriptions for the line item Other tab Part 1 Field descriptions for the line item Other tab This table explains the fields on the Other tab Depending on the financial event that you selected some or all of the fields are available Unless noted the fields apply to both Supplies and Procurement Field Description Line Item Number An alphanumeric identifier for the line item This can be the line item number provided by your host system Intrastat Commodity Code The Intrastate commodity code for the line item Intrastat Commodity Codes are part of a classification system used in the European Union to classify goods and services For a list of values accepted see the filing instructions for each country where you file an Intrastat report Store Location Code An alphanumeric value that can be used for tax return filing in jurisdictions that require taxes to be filed for individual retail locations It can include up to 20 characters Mode of Transport A one digit code that indicates the type of vehicle that transported the product across a border For a list of values accepted see the filing instructions for each country where you file an Intrastat report Country of Origin ISO Code The 3 digit International Organization for Standardization ISO code of the country where the product was produced or manufactured ",
#                     "order": 1
#                 },
#                 {
#                     "id": "COSTools:en:185634:2",
#                     "label": "chunk",
#                     "type": "vertex",
#                     "title": "O Series Transaction Tester Other tab for line items",
#                     "heading": "Field descriptions for the line item Other tab Part 2",
#                     "md": "Field descriptions for the line item Other tab Part 2 Field descriptions for the line item Other tab This table explains the fields on the Other tab Depending on the financial event that you selected some or all of the fields are available Unless noted the fields apply to both Supplies and Procurement Field Description Export Procedure Specifies the export import procedure that is used Examples include goods shipped temporarily for further manufacturing by a subcontractor and goods shipped to their final destination by a subcontractor after processing Nature of transaction A code that indicates the type of transaction being declared for Intrastat purposes For a list of values accepted see the filing instructions for each country where you file an Intrastat report Sync ID An alphanumeric identifier for synchronizing the line item record in the Tax Journal with information in the host system in case the transaction is altered or canceled after tax was calculated It can include up to 25 characters To synchronize a line item you must also have supplied a Sync ID for the transaction Title Transfer Indicates the location where the title of goods actually changes hands from seller to buyer This indicator is evaluated to determine the proper situs or place of supply conclusion for the transaction Chain Transaction Phase Identifies a phase within a series of transactions in which multiple invoices are raised with only a single movement of goods Tax Assist rules can evaluate this indicator along with other transaction facts to set the title transfer value and determine an appropriate taxability conclusion ",
#                     "order": 2
#                 },
#                 {
#                     "id": "COSTools:en:185634:3",
#                     "label": "chunk",
#                     "type": "vertex",
#                     "title": "O Series Transaction Tester Other tab for line items",
#                     "heading": "Field descriptions for the line item Other tab Part 3",
#                     "md": "Field descriptions for the line item Other tab Part 3 Field descriptions for the line item Other tab This table explains the fields on the Other tab Depending on the financial event that you selected some or all of the fields are available Unless noted the fields apply to both Supplies and Procurement Field Description Commodity Code Type The type of commodity code to be used with the line item Commodity codes are part of product and service classification systems that are used in some jurisdictions to classify goods and or services O Series supports UNSPSC codes NCM codes Service codes and HSN codes Commodity Code The commodity code for the line item The type of commodity code must be selected in the Commodity Code Type field Statistical Value The net domestic value fair market value or customs value of a product when it crosses a border This value is needed for each exported or imported item for INTRASTAT and EXTRASTAT declarations in the European Union EU Statistical Value Currency The currency type for the statistical value if it is different from the transactional currency This is a three character ISO currency code for the statistical value entered for the transaction Recoverable Date Procurement The date when the paid value added tax may be recovered It can be provided for Accrual Buyer Input Tax Distribute Tax and Purchase Order financial events If this date is not supplied the Tax Date set on the Basic tab is used ",
#                     "order": 3
#                 },
#                 {
#                     "id": "COSTools:en:185634:4",
#                     "label": "chunk",
#                     "type": "vertex",
#                     "title": "O Series Transaction Tester Other tab for line items",
#                     "heading": "Field descriptions for the line item Other tab Part 4",
#                     "md": "Field descriptions for the line item Other tab Part 4 Field descriptions for the line item Other tab This table explains the fields on the Other tab Depending on the financial event that you selected some or all of the fields are available Unless noted the fields apply to both Supplies and Procurement Field Description Blocking Override Percent Procurement For line items that include blocking the percentage that overrides the standard percentage when calculating recoverable input VAT The format of this field is nn nn To set up 15 5 enter 15 5 When you click in or tab to a different field 15 50 displays This field applies to Accrual Asset Goods Movement Distribute Tax ERS and Purchase Order financial events Partial Exempt Recov Override Percent Procurement For transactions that include partial exemptions the percentage that overrides the standard percentage when calculating recoverable input VAT The format of this field is nn nn To set up 15 5 enter 15 5 When you click in or tab to a different field 15 50 displays This field applies to Accrual Asset Goods Movement Distribute Tax ERS and Purchase Order financial events Accumulation Location Supplies The location to be passed in an Accumulate by Location line item Material Origin Supplies Identifies where material goods originated Material origin is specified in situations where tax rates apply differently depending on the original source of material goods that were used in manufacturing Material Origin taxability is used principally in Brazil and India Taxable Amount The taxable amount for the line item as provided by the ERP This amount is shown in the default currency of the specific filing entity or taxpayer The amount is not used in any calculations but is passed to the Tax Journal and the Reporting database for reporting purposes ",
#                     "order": 4
#                 }
#             ]
#         }
#     ]
# }

# %%
from fns.graph_construction import download_af_files
import json
import nest_asyncio
nest_asyncio.apply()


test_targets = [
    "IrisProductGuide",
    "GettingStartedWithProductDocumentation",
    "OSeries9ReleaseNotesCloud",
    "WhatsNewinVertexCloudfor2022",
    "COSOverview",
    "Vertexe-InvoicingReleaseNotes",
    "OSInstallationGuide",
    "ITIOverview",
    "AccessConnectorDocumentation",
    "AccountandBillingforVertexCloud",
    "AddOnFeaturesinVertexCloud",
    "AddressCleansing",
    "AdobeCommerce-ReleaseNotes",
]

# download_af_files("test") # , targeted_products=test_targets)

# %% [markdown]
# #### For Error: `CERTIFICATE_VERIFY_FAILED` error in websocket-client
#
# This can happen on MacOS when connecting to a websocket server. To fix this, run
# the `Install Certificates.command` script that comes with Python.
#
# ```sh
# open "/Applications/Python 3.<your version>/Install Certificates.command"
# ```

# %%
import json
import nest_asyncio
from fns.azure_fns import upsert_node, exec_gremlin, upsert_edges, prune
nest_asyncio.apply()

nodes = [
    {"node_id": "tu", "node_type": "person", "properties": {"order": 1}},
    {"node_id": "kim", "node_type": "person", "properties": {"order": 1}},
    {"node_id": "logan", "node_type": "person", "properties": {"order": 2}},
    {"node_id": "william", "node_type": "person", "properties": {"order": 3}},
    {"node_id": "amelia", "node_type": "person", "properties": {"order": 3}},
    {"node_id": "sung", "node_type": "person", "properties": {"order": 3}},
    {"node_id": "kyo", "node_type": "person", "properties": {"order": 3}},
    {"node_id": "catherine", "node_type": "person", "properties": {"order": 3}},
]


edges = [
    {"from_id": "tu", "rel_to": "younger", "to_id": "kim"},
    {"from_id": "kim", "rel_to": "parent", "to_id": "logan"},
    {"from_id": "logan", "rel_to": "parent", "to_id": "william"},
    {"from_id": "logan", "rel_to": "parent", "to_id": "amelia"},
    {"from_id": "sung", "to_id": "kim", "rel_to": "parent"},
    {"from_id": "kyo", "to_id": "kim", "rel_to": "parent"},
    {"from_id": "kim", "to_id": "catherine", "rel_to": "parent"},
    {"from_id": "kyo", "to_id": "tu", "rel_to": "parent"},
    {"from_id": "tu", "to_id": "sung", "rel_from": "parent", "rel_to": "child"},
]

# nodes_out = [upsert_node(**node) for node in nodes]
# edges_out = [upsert_edges(**edge) for edge in edges]
# pruned = prune("logan")

# print(json.dumps(nodes_out, indent=2))
# print(json.dumps(edges_out, indent=2))
# print(json.dumps(pruned, indent=2))
